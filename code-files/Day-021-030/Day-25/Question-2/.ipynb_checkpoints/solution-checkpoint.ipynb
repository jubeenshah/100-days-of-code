# %%
def welcome(n,m):
    pattern = [('.|.'*(2*i + 1)).center(m, '-') for i in range(n//2)]
    print('\n'.join(pattern + ['Jubeen'.center(m, '-')] + pattern[::-1]))

n, m = map(int,input().split())
welcome(n,m)
# Out:
# 20 60
# ----------------------------.|.-----------------------------
# -------------------------.|..|..|.--------------------------
# ----------------------.|..|..|..|..|.-----------------------
# -------------------.|..|..|..|..|..|..|.--------------------
# ----------------.|..|..|..|..|..|..|..|..|.-----------------
# -------------.|..|..|..|..|..|..|..|..|..|..|.--------------
# ----------.|..|..|..|..|..|..|..|..|..|..|..|..|.-----------
# -------.|..|..|..|..|..|..|..|..|..|..|..|..|..|..|.--------
# ----.|..|..|..|..|..|..|..|..|..|..|..|..|..|..|..|..|.-----
# -.|..|..|..|..|..|..|..|..|..|..|..|..|..|..|..|..|..|..|.--
# ---------------------------Jubeen---------------------------
# -.|..|..|..|..|..|..|..|..|..|..|..|..|..|..|..|..|..|..|.--
# ----.|..|..|..|..|..|..|..|..|..|..|..|..|..|..|..|..|.-----
# -------.|..|..|..|..|..|..|..|..|..|..|..|..|..|..|.--------
# ----------.|..|..|..|..|..|..|..|..|..|..|..|..|.-----------
# ...
